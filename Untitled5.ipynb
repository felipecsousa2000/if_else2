# %% [markdown]
# <a href="https://colab.research.google.com/github/felipecsousa2000/if_else2/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
entrega = input("Digite o tipo de entrega: ")
if entrega == "padrão":
  print("Entrega padrão: R$10,00")
elif entrega == "expresso":
  print("Entrega expresso : R$ 20,00")
else:
  print("Opção de entrega inválida")
